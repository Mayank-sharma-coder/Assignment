# %% [markdown]
# ## Ques1

# %%
#Create a class named Student with attributes:-

class Student:
    name = "Rahul"
    age = 20
    course = "Data Science"

s = Student()

print("Name:", s.name)
print("Age:", s.age)
print("Course:", s.course)
# Out:
# Name: Rahul
# Age: 20
# Course: Data Science

# %% [markdown]
# ## Ques2

# %%
#Create a class named Car with attributes:-

class Car:
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price

car1 = Car("swift", "Innova", 2000000)
car2 = Car("defender", "City", 1500000)

print(car1.brand, car1.model, car1.price)
print(car2.brand, car2.model, car2.price)
# Out:
# swift Innova 2000000
# defender City 1500000

# %% [markdown]
# ## Ques3

# %%
#Create a class named Employee and use a constructor (__init__) to
#initialize:-

class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

e = Employee(101, "Mohit", 50000)

print(e.employee_id)
print(e.name)
print(e.salary)
# Out:
# 101
# Mohit
# 50000

# %% [markdown]
# ## Ques4

# %%
#Create a class named Rectangle with attributes:-

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        print("Area =", self.length * self.width)

r = Rectangle(6, 3)
r.area()
# Out:
# Area = 18

# %% [markdown]
# ## Ques5

# %%
#Create a class named Circle with an attribute radius.
#Create a method that calculates and prints the area of the circle.

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Area =", 5.34 * self.radius )

c = Circle(9)
c.area()
# Out:
# Area = 48.06

# %% [markdown]
# ## Ques6

# %%
#Create a class named BankAccount with:-

# %% [markdown]
# ## Ques7

# %%
#Create a class named Animal with a method sound().
#Create a child class Dog that overrides the sound() method and prints "Bark"

class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

d = Dog()
d.sound()
# Out:
# Bark

# %% [markdown]
# ## Ques8

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s = Student("Mayank", 19, 31)

print("Name:", s.name)
print("Age:", s.age)
print("Roll No:", s.roll_no)
# Out:
# Name: Mayank
# Age: 19
# Roll No: 31

# %% [markdown]
# ## Ques9

# %%
class Calculator:
    def add(self, a, b):
        print("Add =", a + b)

    def subtract(self, a, b):
        print("Subtract =", a - b)

    def multiply(self, a, b):
        print("Multiply =", a * b)

    def divide(self, a, b):
        print("Divide =", a / b)

c = Calculator()

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

c.add(a, b)
c.subtract(a, b)
c.multiply(a, b)
c.divide(a, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 16
#      12         print("Divide =", a / b)
#      13
#      14 c = Calculator()
#      15
# ---> 16 a = int(input("Enter first number: "))
#      17 b = int(input("Enter second number: "))
#      18
#      19 c.add(a, b)
#
# ValueError: invalid literal for int() with base 10: '2+3'

# %% [markdown]
# ## Ques10

# %%
class LibraryBook:
    def __init__(self, book_name, author, price):
        self.book_name = book_name
        self.author = author
        self.price = price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 13
#       9 b1 = LibraryBook("Python", "Ramesh", 300)
#      10 b2 = LibraryBook("Data Science", "Suresh", 500)
#      11 b3 = LibraryBook("AI Basics", "Mahesh", 400)
#      12
# ---> 13 b1.display_book_info()
#      14 b2.display_book_info()
#      15 b3.display_book_info()
#
# AttributeError: 'LibraryBook' object has no attribute 'display_book_info'
